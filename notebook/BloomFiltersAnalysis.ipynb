# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
#1
#plot0timetoload.py
#project_dir = "/Users/Lyudmila/project2021/bloom-app/"
project_dir = "./"
filename = project_dir +"plots/lookup.csv"
filename2 = project_dir + "plots/timetoload.csv"
dfload = pd.read_csv(filename2) 
df = pd.read_csv(filename)  
df.drop('negcount', axis=1, inplace=True)
df.drop('filtername', axis=1, inplace=True)
df['positivecount'] = df['positivecount'].apply(lambda x: (x /1000000.))

df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="<200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(df.head())
#df.info()
dfneg=df[df.neg==True]
print(dfneg.head())
dfpos=df[df.neg==False]
print(dfpos.head())


dfa=dfneg[dfneg.maxl=="all"] #
print(dfa.head())


dfb=dfneg[dfneg.maxl=="small"]
df.info()
print(dfb.head())


#dfpos=df[df.neg==False]
dfc=dfpos[dfpos.maxl=='all']
dfd=dfpos[dfpos.maxl=='small']
# Out:
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0   True       0.040370    all            3         0.032253  0.029175
# 1  False       1.000000    all            3         0.031903  0.029720
# 2   True       0.040368  small            3         0.032055  0.006020
# 3  False       1.000000  small            3         0.031967  0.006188
# 4   True       0.033811    all            4         0.033257  0.006731
#     neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0  True       0.040370    all            3         0.032253  0.029175
# 2  True       0.040368  small            3         0.032055  0.006020
# 4  True       0.033811    all            4         0.033257  0.006731
# 6  True       0.033888  small            4         0.033101  0.008447
# 8  True       0.032239    all            5         0.034394  0.030313
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# ...

# %%
print(dfload.head())


fig, ax1 = plt.subplots()
fig.suptitle("Bloomfilter: 200 mln capacity; 1247044840 bits (m/n ~6.23) and 0.05 fpr, optimum k=4.3",fontsize = 'small' ,fontweight = 'bold' )

ax2 = ax1.twinx()
sns.lineplot(x = dfload.hashnumber, y = dfload.probability,marker = 'o', ax = ax1, color = 'red')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
#sns.lineplot(x = dfd.number_hash, y = dfd.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
#ax1.fill_between(dfd.number_hash, y1=dfd["mean_avrtime_ms"] - dfd["st_dev"], y2=dfd["mean_avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'blue', ax = ax2)
sns_plot =sns.scatterplot(x=5, y=dfload.probability[dfload.hashnumber == 5],  marker = 'o',color='purple')

ax1.set_xlabel('hash functions (k)')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.set_ylabel('estimated false positive rate (fpr)', color='r')
#ax1.set_ylabel('time to response ms', color='g')
ax2.set_ylabel('time to load min', color='b')


plt.show();
# Out:
#    hashnumber  probability  population  timetoloadsec
# 0           3     0.040416   172723470   11712.834791
# 1           4     0.033887   173299137   12121.447847
# 2           5     0.032424   173516321   12605.613721
# 3           6     0.033790   173572219   12887.928709
# 4           9     0.049846   173266544   14186.557712

# %%
#2
#plot1qtime.py
dfload = pd.read_csv(filename2) 
df = pd.read_csv(filename)  
df.drop('negcount', axis=1, inplace=True)
df.drop('filtername', axis=1, inplace=True)
df['positivecount'] = df['positivecount'].apply(lambda x: (x /1000000.))

df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="<200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(df.head())
#df.info()
dfneg=df[df.neg==True]
print(dfneg.head())
dfpos=df[df.neg==False]
print(dfpos.head())


dfa=dfneg[dfneg.maxl=="all"] #
print(dfa.head())


dfb=dfneg[dfneg.maxl=="small"]
df.info()
print(dfb.head())


#dfpos=df[df.neg==False]
dfc=dfpos[dfpos.maxl=='all']
dfd=dfpos[dfpos.maxl=='small']
# Out:
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0   True       0.040370    all            3         0.032253  0.029175
# 1  False       1.000000    all            3         0.031903  0.029720
# 2   True       0.040368  small            3         0.032055  0.006020
# 3  False       1.000000  small            3         0.031967  0.006188
# 4   True       0.033811    all            4         0.033257  0.006731
#     neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0  True       0.040370    all            3         0.032253  0.029175
# 2  True       0.040368  small            3         0.032055  0.006020
# 4  True       0.033811    all            4         0.033257  0.006731
# 6  True       0.033888  small            4         0.033101  0.008447
# 8  True       0.032239    all            5         0.034394  0.030313
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# ...

# %%
print(dfload.head())


fig, ax1 = plt.subplots()
fig.suptitle("Bloomfilter: 200 mln capacity; 1247044840 bits (m/n ~6.23) and 0.05 fpr, optimum k=4.3",fontsize = 'small' ,fontweight = 'bold' )

#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability,marker = 'o', ax = ax1, color = 'red')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfa.number_hash, y = dfa.mean_avrtime_ms, ax = ax1, color = 'green',label="not in set; all urls",)
sns.lineplot(x = dfb.number_hash, y = dfb.mean_avrtime_ms, ax = ax1, color = 'red',label="not in set; short urls")
sns.lineplot(x = dfc.number_hash, y = dfc.mean_avrtime_ms, ax = ax1, color = 'orange',label="in set; all urls")
sns.lineplot(x = dfd.number_hash, y = dfd.mean_avrtime_ms, ax = ax1, color = 'blue',label="in set; short urls")
sns.set()

#ax1.fill_between(dfd.number_hash, y1=dfd["mean_avrtime_ms"] - dfd["st_dev"], y2=dfd["mean_avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'blue', ax = ax2)
#sns_plot =sns.scatterplot(x=5, y=dfload.probability[dfload.hashnumber == 5],  marker = 'o',color='purple')

ax1.set_xlabel('hash functions (k)')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
#ax1.set_ylabel('estimated false positive rate (fpr)', color='r')
ax1.set_ylabel('mean time to response ms')
#ax2.set_ylabel('time to load min', color='b')




plt.savefig('qtime.png', dpi=400)
plt.show();
# Out:
#    hashnumber  probability  population  timetoloadsec
# 0           3     0.040416   172723470   11712.834791
# 1           4     0.033887   173299137   12121.447847
# 2           5     0.032424   173516321   12605.613721
# 3           6     0.033790   173572219   12887.928709
# 4           9     0.049846   173266544   14186.557712

# %%
#3
#plot1qtime_diffhashes.py
filename = project_dir + "plots/harvest-2020-q-05-multhashes.csv"
filename2 = project_dir +"plots/timetoload.csv"
dfload = pd.read_csv(filename2) 
df = pd.read_csv(filename)  
df.drop('negcount', axis=1, inplace=True)
df.drop('filtername', axis=1, inplace=True)
df['positivecount'] = df['positivecount'].apply(lambda x: (x /1000000.))

#df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="<200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(df.head())
#df.info()
dfneg=df[df.neg==True]
print(dfneg.head())
dfpos=df[df.neg==False]
print(dfpos.head())


dfa=dfneg[dfneg.maxl==0] #
print(dfa.head())


dfb=dfneg[dfneg.maxl==200]
df.info()
print(dfb.head())


#dfpos=df[df.neg==False]
dfc=dfpos[dfpos.maxl==0]
dfd=dfpos[dfpos.maxl==200]
# Out:
#   hashname    neg  positivecount  maxl  number_hs  avrtime_ms    st_dev
# 0      MD5   True       0.032468     0          5    0.035921  0.074233
# 1      MD5  False       0.999998     0          5    0.035419  0.007444
# 2      MD5   True       0.032466   200          5    0.035465  0.049495
# 3      MD5  False       0.999998   200          5    0.035394  0.008588
# 4   SHA256   True       0.032573     0          5    0.036209  0.049859
#   hashname   neg  positivecount  maxl  number_hs  avrtime_ms    st_dev
# 0      MD5  True       0.032468     0          5    0.035921  0.074233
# 2      MD5  True       0.032466   200          5    0.035465  0.049495
# 4   SHA256  True       0.032573     0          5    0.036209  0.049859
# 6   SHA256  True       0.032619   200          5    0.035830  0.010792
# 8   SHA384  True       0.032505     0          5    0.035488  0.009909
#   hashname    neg  positivecount  maxl  number_hs  avrtime_ms    st_dev
# ...

# %%
print(dfload.head())


fig, ax1 = plt.subplots()
fig.suptitle("Bloomfilter: 200 mln capacity; 1247044840 bits (m/n ~6.23) and 0.05 fpr, k=5",fontsize = 'small' ,fontweight = 'bold' )

#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability,marker = 'o', ax = ax1, color = 'red')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfa.hashname, y = dfa.avrtime_ms, ax = ax1, color = 'green',label="not in set; all urls",marker = 'o')
sns.lineplot(x = dfb.hashname, y = dfb.avrtime_ms, ax = ax1, color = 'red',label="not in set; short urls",marker = 'o')
sns.lineplot(x = dfc.hashname, y = dfc.avrtime_ms, ax = ax1, color = 'orange',label="in set; all urls",marker = 'o')
sns.lineplot(x = dfd.hashname, y = dfd.avrtime_ms, ax = ax1, color = 'blue',label="in set; short urls",marker = 'o')
sns.set()

#ax1.fill_between(dfd.number_hash, y1=dfd["mean_avrtime_ms"] - dfd["st_dev"], y2=dfd["mean_avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'blue', ax = ax2)
#sns_plot =sns.scatterplot(x=5, y=dfload.probability[dfload.hashnumber == 5],  marker = 'o',color='purple')

ax1.set_xlabel('hash methods')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#ax1.set_ylabel('estimated false positive rate (fpr)', color='r')
ax1.set_ylabel('mean time to response ms')
#ax2.set_ylabel('time to load min', color='b')




plt.savefig('qtimediffhash.png', dpi=400)
plt.show();
# Out:
#    hashnumber  probability  population  timetoloadsec
# 0           3     0.040416   172723470   11712.834791
# 1           4     0.033887   173299137   12121.447847
# 2           5     0.032424   173516321   12605.613721
# 3           6     0.033790   173572219   12887.928709
# 4           9     0.049846   173266544   14186.557712

# %%
#4
#plot2timetoloaddiffhashes.py


filename = project_dir +"plots/lookup.csv"
filename2 = project_dir + "plots/load_hashes.csv"
dfload = pd.read_csv(filename2) 
df = pd.read_csv(filename)  
df.drop('negcount', axis=1, inplace=True)
df.drop('filtername', axis=1, inplace=True)
df['positivecount'] = df['positivecount'].apply(lambda x: (x /1000000.))

df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="<200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(df.head())
#df.info()
dfneg=df[df.neg==True]
print(dfneg.head())
dfpos=df[df.neg==False]
print(dfpos.head())


dfa=dfneg[dfneg.maxl=="all"] #
print(dfa.head())


dfb=dfneg[dfneg.maxl=="small"]
df.info()
print(dfb.head())


#dfpos=df[df.neg==False]
dfc=dfpos[dfpos.maxl=='all']
dfd=dfpos[dfpos.maxl=='small']
# Out:
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0   True       0.040370    all            3         0.032253  0.029175
# 1  False       1.000000    all            3         0.031903  0.029720
# 2   True       0.040368  small            3         0.032055  0.006020
# 3  False       1.000000  small            3         0.031967  0.006188
# 4   True       0.033811    all            4         0.033257  0.006731
#     neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0  True       0.040370    all            3         0.032253  0.029175
# 2  True       0.040368  small            3         0.032055  0.006020
# 4  True       0.033811    all            4         0.033257  0.006731
# 6  True       0.033888  small            4         0.033101  0.008447
# 8  True       0.032239    all            5         0.034394  0.030313
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# ...

# %%
print(dfload.head())


fig, ax1 = plt.subplots()
fig.suptitle("Bloomfilter: 200 mln capacity; 1247044840 bits (m/n ~6.23) and 0.05 fpr, optimum k=4.3",fontsize = 'small' ,fontweight = 'bold' )

ax2 = ax1.twinx()
sns.barplot(x = dfload.hashname, y = (dfload.total-dfload.dedup) , ax = ax1,color = 'green',alpha=0.5)
sns.barplot(x = dfload.hashname, y = dfload.timetoloadsec/60 , ax = ax2, color='blue',alpha=0.3)
sns.set()
#sns.lineplot(x = dfload.hashname, y = (dfload.estimate) , ax = ax1,color = 'r')
#sns.lineplot(x = dfload.hashname, y = dfload.probability,marker = 'o', ax = ax1, color='green')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
#sns.lineplot(x = dfd.number_hash, y = dfd.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
#ax1.fill_between(dfd.number_hash, y1=dfd["mean_avrtime_ms"] - dfd["st_dev"], y2=dfd["mean_avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)

#sns_plot =sns.scatterplot(x=5, y=dfload.probability[dfload.hashnumber == 5],  marker = 'o',color='purple')
#plt.xticks(rotation=45)
ax1.set_xlabel('hash functions (k=5)')

ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-45,labelsize=10)
#ax1.set_ylabel('estimated false positive rate (fpr)',color='g')
ax1.set_ylabel('#dublicates',color='g')
#ax1.set_ylabel('time to response ms', color='g')
ax2.set_ylabel('time to load min',color='b')
#plt.setp(plt.get_xticklabels(), rotation=90)
#loc, labels = plt.xticks()
#my.set_xticklabels(labels, rotation=45)
#my.set_xticklabels(my.get_xticklabels(),rotation=45, horizontalalignment='right')
fig.tight_layout()
plt.show();
#fig = plt.get_figure()
fig.savefig('/Users/Lyudmila/project2021/bloom-app/plots/timetoloaddifferenthashes.png')
# Out:
#     hashname  timetoloadsec  probability      total      dedup      estimate
# 0        MD5   13217.920239     0.032420  180379433  173514613  1.747241e+08
# 1     SHA256   13449.350930     0.032416  180379433  173512065  1.747173e+08
# 2     SHA384   13137.056690     0.032421  180379433  173513845  1.747250e+08
# 3     SHA512   13121.043975     0.032419  180379433  173513867  1.747220e+08
# 4  Murmur3KM   12707.345230     0.029690  180379433  173267460  1.703484e+08

# %%
#5
#plot_timetoloaddiffprob.py
filename = project_dir+"plots/load-prob-multprob.csv"
#filename2 = "/Users/Lyudmila/project2021/bloom-app/plots/load_hashes.csv"
#dfload = pd.read_csv(filename2) 
dfload = pd.read_csv(filename)  
#fpr,probability,name,timetoloadsec,size
dfload.drop('name', axis=1, inplace=True)
#df.drop('filtername', axis=1, inplace=True)
dfload['size1'] = dfload['size'].apply(lambda x: (x * 0.000000125))

#df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="<200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(dfload.head())
dfload.info()
# Out:
#      fpr  probability  timetoloadsec        size       size1
# 0  0.005     0.004171   12826.550921  2147483647  268.435456
# 1  0.010     0.006568   12846.503940  1917011685  239.626461
# 2  0.050     0.032424   12605.613721  1247044840  155.880605
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
# fpr              3 non-null float64
# probability      3 non-null float64
# timetoloadsec    3 non-null float64
# size             3 non-null int64
# size1            3 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 248.0 bytes

# %%
print(dfload.head())


fig, ax1 = plt.subplots()
fig.suptitle("Bloomfilter: 200 mln capacity, Murmur3, k=5",fontsize = 'small' ,fontweight = 'bold' )

ax2 = ax1.twinx()

sns.lineplot(x = dfload.fpr, y = dfload.timetoloadsec/60 ,  marker = 'o', ax = ax2, color='blue')
sns.lineplot(x = dfload.fpr, y = dfload.size1 , ax = ax1,  marker = 'o', color = 'green')
#sns.scatterplot(x = dfload.fpr, y = dfload.probability , ax = ax1,  marker = 'o', color = 'red')
sns.set()
#sns.lineplot(x = dfload.hashname, y = (dfload.estimate) , ax = ax1,color = 'r')
#sns.lineplot(x = dfload.hashname, y = dfload.probability,marker = 'o', ax = ax1, color='green')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
#sns.lineplot(x = dfd.number_hash, y = dfd.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
#ax1.fill_between(dfd.number_hash, y1=dfd["mean_avrtime_ms"] - dfd["st_dev"], y2=dfd["mean_avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)

#sns_plot =sns.scatterplot(x=5, y=dfload.probability[dfload.hashnumber == 5],  marker = 'o',color='purple')
#plt.xticks(rotation=45)
ax1.set_xlabel('fpr')

#ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

#ax1.tick_params(axis="x",labelrotation=-45,labelsize=10)
#ax1.set_ylabel('estimated false positive rate (fpr)',color='g')
ax2.set_ylabel('size in MB',color='green')
ax2.set(ylim=(100, 300))
#ax1.set_ylabel('time to response ms', color='g')
ax1.set_ylabel('time to load min',color='blue')
#plt.setp(plt.get_xticklabels(), rotation=90)
#loc, labels = plt.xticks()
#my.set_xticklabels(labels, rotation=45)
#my.set_xticklabels(my.get_xticklabels(),rotation=45, horizontalalignment='right')
fig.tight_layout()
#fig = plt.get_figure()
#fig.savefig('/Users/Lyudmila/project2021/bloom-app/plots/timetoloadsizesdifpr.png')

plt.savefig('timetoloadsizesdifpr.png', dpi=400)
plt.show();
# Out:
#      fpr  probability  timetoloadsec        size       size1
# 0  0.005     0.004171   12826.550921  2147483647  268.435456
# 1  0.010     0.006568   12846.503940  1917011685  239.626461
# 2  0.050     0.032424   12605.613721  1247044840  155.880605

# %%
#6
#plotmultiplehashesfish.py
filename = project_dir +"plots/harvest-2020-q-05-multhashes.csv"
filename2 = project_dir+"plots/load_hashes.csv"
dfload = pd.read_csv(filename2) 
df = pd.read_csv(filename)  
df.drop('negcount', axis=1, inplace=True)
df.drop('filtername', axis=1, inplace=True)
df['positivecount'] = df['positivecount'].apply(lambda x: (x /1000000.))

#df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(df.head())
#df.info()
dfneg=df[df.neg==True]
print(dfneg.head())
dfpos=df[df.neg==False]
print(dfpos.head())


dfa=dfneg[dfneg.maxl==0] #
print(dfa.head())


dfb=dfneg[dfneg.maxl==200]
df.info()
print(dfb.head())


#dfpos=df[df.neg==False]
dfc=dfpos[dfpos.maxl==0]
dfd=dfpos[dfpos.maxl==200]
# Out:
#   hashname    neg  positivecount  maxl  number_hs  avrtime_ms    st_dev
# 0      MD5   True       0.032468     0          5    0.035921  0.074233
# 1      MD5  False       0.999998     0          5    0.035419  0.007444
# 2      MD5   True       0.032466   200          5    0.035465  0.049495
# 3      MD5  False       0.999998   200          5    0.035394  0.008588
# 4   SHA256   True       0.032573     0          5    0.036209  0.049859
#   hashname   neg  positivecount  maxl  number_hs  avrtime_ms    st_dev
# 0      MD5  True       0.032468     0          5    0.035921  0.074233
# 2      MD5  True       0.032466   200          5    0.035465  0.049495
# 4   SHA256  True       0.032573     0          5    0.036209  0.049859
# 6   SHA256  True       0.032619   200          5    0.035830  0.010792
# 8   SHA384  True       0.032505     0          5    0.035488  0.009909
#   hashname    neg  positivecount  maxl  number_hs  avrtime_ms    st_dev
# ...

# %%
print(dfload.head())

afig = plt.figure()
sns.color_palette("husl",8)
#sns.palplot(sns.color_palette("husl", 8))
afig.subplots_adjust(hspace=0.9, wspace=0.8)
afig.suptitle("Bloomfilter: 200 mln capacity;1247044840 bits (m/n ~6.23) and 0.05 target probability,k=5",fontsize = 'small' ,fontweight = 'bold' )
ax1 = afig.add_subplot(2, 2, 1)
#ax1.set_title('Response Time vs hash number')
#fig, ax1 = plt.subplots()
ax1.set_title('not in set; all  urls lengths')
ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfa.hashname, y = dfa.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfa.hashname, y1=dfa["avrtime_ms"] - dfa["st_dev"], y2=dfa["avrtime_ms"] + dfa["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)
sns.lineplot(x = dfa.hashname, y = dfa.positivecount, ax = ax2, color = 'red')
ax1.set_xlabel('hash method')
#ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
#ax2.set_ylabel('timetoload min', color='r')
ax2.set_ylabel('probablity', color='r')

ax1 = afig.add_subplot(2, 2, 2)

#fig, ax1 = plt.subplots()
ax1.set_title('not in set;  urls lengths <200')
ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfb.hashname, y = dfb.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfb.hashname, y1=dfb["avrtime_ms"] - dfb["st_dev"], y2=dfb["avrtime_ms"] + dfb["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)
sns.lineplot(x = dfb.hashname, y = dfb.positivecount, ax = ax2, color = 'red')
#yy=dfb.positivecount[dfb.number_hash == 5]
#print(yy)
#sns.scatterplot(x=5, y=dfb.positivecount[dfb.number_hash == 5], color='purple')
ax1.set_xlabel('hash method')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax2.set_ylabel('probablity', color='r')

#plt.annotate("optimum k", (4.3, 4))

ax1 = afig.add_subplot(2, 2, 3)

#fig, ax1 = plt.subplots()
ax1.set_title('in set;  all urls lengths')
#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfc.hashname, y = dfc.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfc.hashname, y1=dfc["avrtime_ms"] - dfc["st_dev"], y2=dfc["avrtime_ms"] + dfc["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)

ax1.set_xlabel('hash method')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
ax1 = afig.add_subplot(2, 2, 4)

#fig, ax1 = plt.subplots()
ax1.set_title('in set;   urls lengths <200')
#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfd.hashname, y = dfd.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfd.hashname, y1=dfd["avrtime_ms"] - dfd["st_dev"], y2=dfd["avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)

ax1.set_xlabel('hash method')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#plt.title("Bloomfilter: 200 mln capacity;1247044840 bits (m/n ~6.23) and 0.05 target probability")
plt.savefig('multiplehashesfish.png', dpi=400)
plt.show();print(dfload.head())

afig = plt.figure()
sns.color_palette("husl",8)
#sns.palplot(sns.color_palette("husl", 8))
afig.subplots_adjust(hspace=0.9, wspace=0.8)
afig.suptitle("Bloomfilter: 200 mln capacity;1247044840 bits (m/n ~6.23) and 0.05 target probability,k=5",fontsize = 'small' ,fontweight = 'bold' )
ax1 = afig.add_subplot(2, 2, 1)
#ax1.set_title('Response Time vs hash number')
#fig, ax1 = plt.subplots()
ax1.set_title('not in set; all  urls lengths')
ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfa.hashname, y = dfa.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfa.hashname, y1=dfa["avrtime_ms"] - dfa["st_dev"], y2=dfa["avrtime_ms"] + dfa["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)
sns.lineplot(x = dfa.hashname, y = dfa.positivecount, ax = ax2, color = 'red')
ax1.set_xlabel('hash method')
#ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
#ax2.set_ylabel('timetoload min', color='r')
ax2.set_ylabel('probablity', color='r')

ax1 = afig.add_subplot(2, 2, 2)

#fig, ax1 = plt.subplots()
ax1.set_title('not in set;  urls lengths <200')
ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfb.hashname, y = dfb.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfb.hashname, y1=dfb["avrtime_ms"] - dfb["st_dev"], y2=dfb["avrtime_ms"] + dfb["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)
sns.lineplot(x = dfb.hashname, y = dfb.positivecount, ax = ax2, color = 'red')
#yy=dfb.positivecount[dfb.number_hash == 5]
#print(yy)
#sns.scatterplot(x=5, y=dfb.positivecount[dfb.number_hash == 5], color='purple')
ax1.set_xlabel('hash method')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax2.set_ylabel('probablity', color='r')

#plt.annotate("optimum k", (4.3, 4))

ax1 = afig.add_subplot(2, 2, 3)

#fig, ax1 = plt.subplots()
ax1.set_title('in set;  all urls lengths')
#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfc.hashname, y = dfc.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfc.hashname, y1=dfc["avrtime_ms"] - dfc["st_dev"], y2=dfc["avrtime_ms"] + dfc["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)

ax1.set_xlabel('hash method')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
ax1 = afig.add_subplot(2, 2, 4)

#fig, ax1 = plt.subplots()
ax1.set_title('in set;   urls lengths <200')
#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfd.hashname, y = dfd.avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfd.hashname, y1=dfd["avrtime_ms"] - dfd["st_dev"], y2=dfd["avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)

ax1.set_xlabel('hash method')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.tick_params(axis="x",labelrotation=-40,labelsize=7)
#plt.title("Bloomfilter: 200 mln capacity;1247044840 bits (m/n ~6.23) and 0.05 target probability")
plt.savefig('multiplehashesfish.png', dpi=400)
plt.show();
# Out:
#     hashname  timetoloadsec  probability      total      dedup      estimate
# 0        MD5   13217.920239     0.032420  180379433  173514613  1.747241e+08
# 1     SHA256   13449.350930     0.032416  180379433  173512065  1.747173e+08
# 2     SHA384   13137.056690     0.032421  180379433  173513845  1.747250e+08
# 3     SHA512   13121.043975     0.032419  180379433  173513867  1.747220e+08
# 4  Murmur3KM   12707.345230     0.029690  180379433  173267460  1.703484e+08
#     hashname  timetoloadsec  probability      total      dedup      estimate
# 0        MD5   13217.920239     0.032420  180379433  173514613  1.747241e+08
# 1     SHA256   13449.350930     0.032416  180379433  173512065  1.747173e+08
# 2     SHA384   13137.056690     0.032421  180379433  173513845  1.747250e+08
# 3     SHA512   13121.043975     0.032419  180379433  173513867  1.747220e+08
# 4  Murmur3KM   12707.345230     0.029690  180379433  173267460  1.703484e+08

# %%
#7
#plotqwithmurmu3_fish.py
filename = project_dir +"plots/lookup.csv"
filename2 = project_dir + plots/timetoload.csv"
dfload = pd.read_csv(filename2) 
df = pd.read_csv(filename)  
df.drop('negcount', axis=1, inplace=True)
df.drop('filtername', axis=1, inplace=True)
df['positivecount'] = df['positivecount'].apply(lambda x: (x /1000000.))

df['maxl'] = df['maxl'].apply(lambda x: "small" if x=="<200" else "all")
#df["maxl"] = df["maxl"].astype("|S")
print(df.head())
#df.info()
dfneg=df[df.neg==True]
print(dfneg.head())
dfpos=df[df.neg==False]
print(dfpos.head())


dfa=dfneg[dfneg.maxl=="all"] #
print(dfa.head())


dfb=dfneg[dfneg.maxl=="small"]
df.info()
print(dfb.head())


#dfpos=df[df.neg==False]
dfc=dfpos[dfpos.maxl=='all']
dfd=dfpos[dfpos.maxl=='small']
# Out:
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0   True       0.040370    all            3         0.032253  0.029175
# 1  False       1.000000    all            3         0.031903  0.029720
# 2   True       0.040368  small            3         0.032055  0.006020
# 3  False       1.000000  small            3         0.031967  0.006188
# 4   True       0.033811    all            4         0.033257  0.006731
#     neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# 0  True       0.040370    all            3         0.032253  0.029175
# 2  True       0.040368  small            3         0.032055  0.006020
# 4  True       0.033811    all            4         0.033257  0.006731
# 6  True       0.033888  small            4         0.033101  0.008447
# 8  True       0.032239    all            5         0.034394  0.030313
#      neg  positivecount   maxl  number_hash  mean_avrtime_ms    st_dev
# ...

# %%
print(dfload.head())

afig = plt.figure()
sns.color_palette("husl",8)
#sns.palplot(sns.color_palette("husl", 8))
afig.subplots_adjust(hspace=0.6, wspace=0.8)
afig.suptitle("Bloomfilter: 200 mln capacity;1247044840 bits (m/n ~6.23) and 0.05 target probability",fontsize = 'small' ,fontweight = 'bold' )
ax1 = afig.add_subplot(2, 2, 1)
#ax1.set_title('Response Time vs hash number')
#fig, ax1 = plt.subplots()
ax1.set_title('not in set; all  urls lengths')
ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfa.number_hash, y = dfa.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfa.number_hash, y1=dfa["mean_avrtime_ms"] - dfa["st_dev"], y2=dfa["mean_avrtime_ms"] + dfa["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)
sns.lineplot(x = dfa.number_hash, y = dfa.positivecount, ax = ax2, color = 'red')
ax1.set_xlabel('hash#')
#ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

#ax1.tick_params(axis="x",labelrotation=-45,labelsize=8)
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
#ax2.set_ylabel('timetoload min', color='r')
ax2.set_ylabel('probablity', color='r')

ax1 = afig.add_subplot(2, 2, 2)

#fig, ax1 = plt.subplots()
ax1.set_title('not in set;  urls lengths <200')
ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfb.number_hash, y = dfb.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfb.number_hash, y1=dfb["mean_avrtime_ms"] - dfb["st_dev"], y2=dfb["mean_avrtime_ms"] + dfb["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)
sns.lineplot(x = dfb.number_hash, y = dfb.positivecount, ax = ax2, color = 'red')
yy=dfb.positivecount[dfb.number_hash == 5]
print(yy)
sns.scatterplot(x=5, y=dfb.positivecount[dfb.number_hash == 5], color='purple')
ax1.set_xlabel('hash#')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')
ax2.set_ylabel('probablity', color='r')

#plt.annotate("optimum k", (4.3, 4))

ax1 = afig.add_subplot(2, 2, 3)

#fig, ax1 = plt.subplots()
ax1.set_title('in set;  all urls lengths')
#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfc.number_hash, y = dfc.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfc.number_hash, y1=dfc["mean_avrtime_ms"] - dfc["st_dev"], y2=dfc["mean_avrtime_ms"] + dfc["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)

ax1.set_xlabel('hash#')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')

ax1 = afig.add_subplot(2, 2, 4)

#fig, ax1 = plt.subplots()
ax1.set_title('in set;   urls lengths <200')
#ax2 = ax1.twinx()
#sns.lineplot(x = dfload.hashnumber, y = dfload.probability, ax = ax1, color = 'blue')
#sns.lineplot(x = dfload.hashnumber, y = dfa.positivecount, ax = ax1, color = 'green')
sns.lineplot(x = dfd.number_hash, y = dfd.mean_avrtime_ms, ax = ax1, marker = 'o', color = 'green')
ax1.fill_between(dfd.number_hash, y1=dfd["mean_avrtime_ms"] - dfd["st_dev"], y2=dfd["mean_avrtime_ms"] + dfd["st_dev"], alpha=.4)
#plt.fill_between(x_axis, lower_bound, upper_bound, alpha=.3)
#sns.lineplot(x = dfload.hashnumber, y = dfload.timetoloadsec/60 , marker = 'o', color = 'red', ax = ax2)

ax1.set_xlabel('hash#')
#ax1.set_ylabel('estimated probability', color='b')
ax1.set_ylabel('time to response ms', color='g')

#plt.title("Bloomfilter: 200 mln capacity;1247044840 bits (m/n ~6.23) and 0.05 target probability")
plt.savefig('fish.png', dpi=400)
plt.show();
# Out:
#    hashnumber  probability  population  timetoloadsec
# 0           3     0.040416   172723470   11712.834791
# 1           4     0.033887   173299137   12121.447847
# 2           5     0.032424   173516321   12605.613721
# 3           6     0.033790   173572219   12887.928709
# 4           9     0.049846   173266544   14186.557712
# 10    0.032285
# Name: positivecount, dtype: float64

# %%
#8
#DBF.py
nfilters = [10, 20, 40,100,200]
fprs=[0.05,0.01,0.005,0.003,0.001]
df = pd.DataFrame()
df.assign(fpr='', n10='', n20='', n40='',n100='',n200='')

i=0

while i< len(fprs):
    x=fprs[i]
    print(x)
    #df.loc[i]=fpr=x
    j=0
    
    d={}
    d['fpr']=x 
    while j< len(nfilters):
       
      z='n'+str(nfilters[j]) 
      print(z) 
      y=1-((1-x)**nfilters[j])
      print(y)      
      d[z] = y
      j += 1
    print(d)  
    df=df.append(d,ignore_index=True)   
    i += 1  
print(df.head()) 

fig, ax1 = plt.subplots()

fig.suptitle("Estimated  fpr of Array of identical Bloomfilters"  ,fontweight = 'bold' )
sns.lineplot(x = df.fpr, y=df.n10 ,marker = 'o',label="10")
sns.lineplot(x = df.fpr, y=df.n20 ,marker = 'o',label="20")
sns.lineplot(x = df.fpr, y=df.n40 ,marker = 'o',label="40") 
sns.lineplot(x = df.fpr, y=df.n100 ,marker = 'o',label="100")
sns.lineplot(x = df.fpr, y=df.n200 ,marker = 'o',label="200") 
ax1.set_ylabel('estimated aggregated false positive rate (fpr)')
ax1.set(xlim=(0.001, 0.05))
ax1.set_xlabel('false positive rate (fpr) of individual filter')
plt.savefig('dbf.png', dpi=400)
plt.show();
# Out:
# 0.05
# n10
# 0.4012630607616213
# n20
# 0.6415140775914581
# n40
# 0.8714878434348969
# n100
# 0.994079470779666
# n200
# 0.9999649473337512
# {'fpr': 0.05, 'n10': 0.4012630607616213, 'n20': 0.6415140775914581, 'n40': 0.8714878434348969, 'n100': 0.994079470779666, 'n200': 0.9999649473337512}
# 0.01
# n10
# 0.09561792499119559
# n20
# 0.18209306240276923
# n40
# 0.3310282414303197
# n100
# 0.6339676587267709
# n200
# 0.8660203251420383
# {'fpr': 0.01, 'n10': 0.09561792499119559, 'n20': 0.18209306240276923, 'n40': 0.3310282414303197, 'n100': 0.6339676587267709, 'n200': 0.8660203251420383}
# 0.005
# n10
# 0.048889869534228136
# n20
# 0.09538951972538245
# n40
# 0.18167987897732574
# n100
# 0.3942295635092721
# n200
# 0.6330421782738329
# {'fpr': 0.005, 'n10': 0.048889869534228136, 'n20': 0.09538951972538245, 'n40': 0.18167987897732574, 'n100': 0.3942295635092721, 'n200': 0.6330421782738329}
# 0.003
# n10
# 0.029598223051083172
# n20
# 0.05832039129438471
# n40
# 0.11323951454803927
# ...
